# %% [markdown]
# <a href="https://colab.research.google.com/github/aikokass82-design/home-tasks-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Копия export 250925 - Лист1.csv")
df
# Out:
#           ID                                         Lead title  \
# 0   55518349                                      form857398089
# 1   55518313                                     Lead #55518313
# 2   55518231                                     Lead #55518231
# 3   55518099                                     Lead #55518099
# 4   55518091                                     Lead #55518091
# 5   55518029  https://prog.academy/ua/data-analytics - 25.09...
# 6   55517987  https://prog.academy/ua/frontend#apply - 25.09...
# 7   55517977  https://prog.academy/ua/software-arch#apply - ...
# 8   55517965  https://prog.academy/fullstack-python-eu#apply...
# 9   55517763                                     Lead #55517763
# 10  55517687  https://prog.academy/data-analytics - 25.09.20...
# 11  55517681                                     Lead #55517681
# 12  55517629  https://prog.academy/osnovi#apply - 25.09.2025...
# 13  55517589  https://prog.academy/python#apply - 25.09.2025...
# 14  55517469                                     Lead #55517469
# 15  55517391                                     Lead #55517391
# 16  55517387  https://prog.academy/ua/data-analytics#apply -...
# 17  55516513  https://prog.academy/data-analytics#apply - 25...
# 18  55516511                                     Lead #55516511
#
#     Lead's company          Main contact  Contact's company  \
# 0              NaN                 Бебра                NaN
# 1              NaN       Inna Kuzmenkova                NaN
# 2              NaN          Anastasia ♀▲                NaN
# 3              NaN    Vitalii Shevchenko                NaN
# 4              NaN        Олена Старобор                NaN
# 5              NaN                  Ihor                NaN
# 6              NaN          Ірина Донець                NaN
# 7              NaN                Andrii                NaN
# 8              NaN                 Anton                NaN
# 9              NaN      Nicodemo Cirillo                NaN
# 10             NaN       SERGEY BEKISHEV                NaN
# 11             NaN          Milan Šesták                NaN
# 12             NaN                 Artem                NaN
# 13             NaN                Никита                NaN
# 14             NaN                 настя                NaN
# 15             NaN             Galina Ng                NaN
# 16             NaN                Ggghhj                NaN
# 17             NaN  Viktoriia Bondarenko                NaN
# 18             NaN                   NaN                NaN
#
#       Lead resp. user                                         Lead stage  \
# 0             Татьяна                           Закрыто и не реализовано
# 1   Всеволод Евгиенко                           Закрыто и не реализовано
# 2             Алексей            Закрыто и не реализовано (не актуально)
# 3             Алексей                 ЯЩ (я еще горячий, но уже остываю)
# 4            Алеся В.                 ЯЩ (я еще горячий, но уже остываю)
# 5             Алексей  Закрыто и не реализовано (наберет сам если решит)
# 6             Алексей            Закрыто и не реализовано (не актуально)
# 7            Алеся В.                 ЯЩ (я еще горячий, но уже остываю)
# 8            Алеся В.                Закрыто и не реализовано (недозвон)
# 9   Всеволод Евгиенко                    Закрыто и не реализовано (спам)
# 10            Алексей                                  Получил материалы
# 11  Всеволод Евгиенко                    Закрыто и не реализовано (спам)
# 12           Алеся В.                 ЯЩ (я еще горячий, но уже остываю)
# 13            Алексей                                  Получил материалы
# 14           Алеся В.                    Закрыто и не реализовано (спам)
# 15           Алеся В.                 ЯЩ (я еще горячий, но уже остываю)
# 16            Алексей                    Закрыто и не реализовано (спам)
# 17            Алексей                                  Получил материалы
# 18            Алексей            Закрыто и не реализовано (не актуально)
#
#    Pipeline  Sale         Date Created  ...  TRAF_TYPE (contact)  \
# 0   Продажи     0  25.09.2025 23:43:54  ...                  NaN
# 1   Продажи     0  25.09.2025 22:47:51  ...                  NaN
# 2   Продажи     0  25.09.2025 21:19:05  ...                  NaN
# 3   Продажи     0  25.09.2025 19:09:21  ...                  NaN
# 4   Продажи     0  25.09.2025 19:04:31  ...                  NaN
# 5   Продажи     0  25.09.2025 18:23:03  ...                  NaN
# 6   Продажи     0  25.09.2025 17:51:53  ...                  NaN
# 7   Продажи     0  25.09.2025 17:49:08  ...                  NaN
# 8   Продажи     0  25.09.2025 17:43:52  ...                  NaN
# 9   Продажи     0  25.09.2025 16:39:04  ...                  NaN
# 10  Продажи     0  25.09.2025 16:03:21  ...                  NaN
# 11  Продажи     0  25.09.2025 16:01:23  ...                  NaN
# 12  Продажи     0  25.09.2025 15:38:58  ...                  NaN
# 13  Продажи     0  25.09.2025 15:22:38  ...                  NaN
# 14  Продажи     0  25.09.2025 14:29:07  ...                  NaN
# 15  Продажи     0  25.09.2025 13:58:49  ...                  NaN
# 16  Продажи     0  25.09.2025 13:58:01  ...                  NaN
# 17  Продажи     0   25.09.2025 0:14:03  ...                  NaN
# 18  Продажи     0   25.09.2025 0:12:43  ...                  NaN
#
#    ADV_CAMP (contact) KEYWORD (contact) TRAF_CONT (contact)  \
# 0                 NaN               NaN                 NaN
# 1                 NaN               NaN                 NaN
# 2                 NaN               NaN                 NaN
# 3                 NaN               NaN                 NaN
# 4                 NaN               NaN                 NaN
# 5                 NaN               NaN                 NaN
# 6                 NaN               NaN                 NaN
# 7                 NaN               NaN                 NaN
# 8                 NaN               NaN                 NaN
# 9                 NaN               NaN                 NaN
# 10                NaN               NaN                 NaN
# 11                NaN               NaN                 NaN
# 12                NaN               NaN                 NaN
# 13                NaN               NaN                 NaN
# 14                NaN               NaN                 NaN
# 15                NaN               NaN                 NaN
# 16                NaN               NaN                 NaN
# 17                NaN               NaN                 NaN
# 18                NaN               NaN                 NaN
#
#                      GOOGLE_ID (contact)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13  ae9ce756-0e85-4cbd-8361-467b1e78cec1
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
#
#                                                Note 1  \
# 0                                           рос номер
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   укр, попросил только урок в вотс ап и напишет ...
# 6   разговаривать с нами не хочет потому что сверх...
# 7                          не дозв, написала в ватсап
# 8                  номер не обслуговується, месс. нет
# 9                                                 NaN
# 10  хочет урок и цены в вотс ап, бросаю и наберу п...
# 11                                                NaN
# 12  Дата-аналит. с европ. дипломом\n90 ects\nв тг ...
# 13                      попросил через 15 мин набрать
# 14                                                NaN
# 15                                                NaN
# 16                                   Написал на почту
# 17  укр, закончила учебу бакалавра и учится на маг...
# 18                                                NaN
#
#                                                Note 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                       не дозв, в ватсап не прочитал
# 8                                                 NaN
# 9                                                 NaN
# 10  уточнял подходит ли ему этот курс для контекст...
# 11                                                NaN
# 12                                   жду фото диплома
# 13                                     уже недоступен
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#                                                Note 3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  опять сказал позже перезвонит или перезвонить ...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#                                                Note 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  сказал что хочет по месячно и начинать через н...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#                       Note 5
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13  скинул в тг инфо по нику
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
#
# [19 rows x 106 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["axes.grid"] = True
plt.rcParams["font.size"] = 11
df.head()
# Out:
#          ID      Lead title  Lead's company        Main contact  \
# 0  55518349   form857398089             NaN               Бебра
# 1  55518313  Lead #55518313             NaN     Inna Kuzmenkova
# 2  55518231  Lead #55518231             NaN        Anastasia ♀▲
# 3  55518099  Lead #55518099             NaN  Vitalii Shevchenko
# 4  55518091  Lead #55518091             NaN      Олена Старобор
#
#    Contact's company    Lead resp. user  \
# 0                NaN            Татьяна
# 1                NaN  Всеволод Евгиенко
# 2                NaN            Алексей
# 3                NaN            Алексей
# 4                NaN           Алеся В.
#
#                                 Lead stage Pipeline  Sale  \
# 0                 Закрыто и не реализовано  Продажи     0
# 1                 Закрыто и не реализовано  Продажи     0
# 2  Закрыто и не реализовано (не актуально)  Продажи     0
# 3       ЯЩ (я еще горячий, но уже остываю)  Продажи     0
# 4       ЯЩ (я еще горячий, но уже остываю)  Продажи     0
#
#           Date Created  ...  TRAF_TYPE (contact) ADV_CAMP (contact)  \
# 0  25.09.2025 23:43:54  ...                  NaN                NaN
# 1  25.09.2025 22:47:51  ...                  NaN                NaN
# 2  25.09.2025 21:19:05  ...                  NaN                NaN
# 3  25.09.2025 19:09:21  ...                  NaN                NaN
# 4  25.09.2025 19:04:31  ...                  NaN                NaN
#
#   KEYWORD (contact) TRAF_CONT (contact) GOOGLE_ID (contact)     Note 1 Note 2  \
# 0               NaN                 NaN                 NaN  рос номер    NaN
# 1               NaN                 NaN                 NaN        NaN    NaN
# 2               NaN                 NaN                 NaN        NaN    NaN
# 3               NaN                 NaN                 NaN        NaN    NaN
# 4               NaN                 NaN                 NaN        NaN    NaN
#
#   Note 3 Note 4  Note 5
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN
#
# [5 rows x 106 columns]

# %%
columns = [
    "Date Created",
    "Lead stage",
    "COURSE",
    "utm_source",
    "utm_medium",
    "utm_campaign"
]

df = df[columns]
df["Date Created"] = pd.to_datetime(df["Date Created"], errors="coerce")
df = df.dropna(subset=["Date Created", "Lead stage"])
df
# Out:
#           Date Created                                         Lead stage  \
# 0  2025-09-25 23:43:54                           Закрыто и не реализовано
# 1  2025-09-25 22:47:51                           Закрыто и не реализовано
# 2  2025-09-25 21:19:05            Закрыто и не реализовано (не актуально)
# 3  2025-09-25 19:09:21                 ЯЩ (я еще горячий, но уже остываю)
# 4  2025-09-25 19:04:31                 ЯЩ (я еще горячий, но уже остываю)
# 5  2025-09-25 18:23:03  Закрыто и не реализовано (наберет сам если решит)
# 6  2025-09-25 17:51:53            Закрыто и не реализовано (не актуально)
# 7  2025-09-25 17:49:08                 ЯЩ (я еще горячий, но уже остываю)
# 8  2025-09-25 17:43:52                Закрыто и не реализовано (недозвон)
# 9  2025-09-25 16:39:04                    Закрыто и не реализовано (спам)
# 10 2025-09-25 16:03:21                                  Получил материалы
# 11 2025-09-25 16:01:23                    Закрыто и не реализовано (спам)
# 12 2025-09-25 15:38:58                 ЯЩ (я еще горячий, но уже остываю)
# 13 2025-09-25 15:22:38                                  Получил материалы
# 14 2025-09-25 14:29:07                    Закрыто и не реализовано (спам)
# 15 2025-09-25 13:58:49                 ЯЩ (я еще горячий, но уже остываю)
# 16 2025-09-25 13:58:01                    Закрыто и не реализовано (спам)
# 17 2025-09-25 00:14:03                                  Получил материалы
# 18 2025-09-25 00:12:43            Закрыто и не реализовано (не актуально)
#
#        COURSE utm_source utm_medium utm_campaign
# 0         NaN    unknown    unknown      unknown
# 1         NaN    unknown    unknown      unknown
# 2         NaN    unknown    unknown      unknown
# 3         NaN    unknown    unknown      unknown
# 4         NaN    unknown    unknown      unknown
# 5   7786943.0    unknown    unknown      unknown
# 6    157221.0    unknown    unknown      unknown
# 7    323381.0    unknown    unknown      unknown
# 8    157221.0    unknown    unknown      unknown
# 9         NaN    unknown    unknown      unknown
# 10   157217.0    unknown    unknown      unknown
# 11        NaN    unknown    unknown      unknown
# 12   157215.0    unknown    unknown      unknown
# 13  1232576.0    unknown    unknown      unknown
# 14        NaN    unknown    unknown      unknown
# 15        NaN    unknown    unknown      unknown
# 16  7786943.0    unknown    unknown      unknown
# 17   157217.0    unknown    unknown      unknown
# 18        NaN    unknown    unknown      unknown

# %% [markdown]
# Были оставлены только ключевые поля, необходимые для анализа.
# Дата создания лида приведена к формату datetime.
# Некорректные и пустые строки удалены.

# %%
lead_status = df["Lead stage"].value_counts()

lead_status
# Out:
# Lead stage
# ЯЩ (я еще горячий, но уже остываю)                   5
# Закрыто и не реализовано (спам)                      4
# Закрыто и не реализовано (не актуально)              3
# Получил материалы                                    3
# Закрыто и не реализовано                             2
# Закрыто и не реализовано (недозвон)                  1
# Закрыто и не реализовано (наберет сам если решит)    1
# Name: count, dtype: int64

# %%
lead_status.plot(
    kind="bar",
    title="Распределение лидов по статусам",
)
plt.xlabel("Статус лида")
plt.ylabel("Количество")
plt.show()

# %% [markdown]
# Данный график показывает,
# на каких этапах воронки находятся лиды.

# %%
courses = df["COURSE"].value_counts()

courses
# Out:
# COURSE
# 7786943.0    2
# 157221.0     2
# 157217.0     2
# 323381.0     1
# 157215.0     1
# 1232576.0    1
# Name: count, dtype: int64

# %%
courses.plot(
    kind="pie",
    autopct="%1.1f%%",
    title="Распределение лидов по курсам"
)

plt.ylabel("")
plt.show()

# %% [markdown]
# Анализ позволяет понять,
# какие курсы вызывают наибольший интерес у пользователей.

# %%
leads_by_date = (
    df
    .groupby(df["Date Created"].dt.date)
    .size()
)

leads_by_date
# Out:
# Date Created
# 2025-09-25    19
# dtype: int64

# %% [markdown]
# пик активности,который может быть связаны с запуском рекламных кампаний.

# %%
utm_cols = [
    "utm_source",
    "utm_medium",
    "utm_campaign"
]

df[utm_cols] = df[utm_cols].fillna("unknown")

for col in utm_cols:
    df[col] = df[col].str.lower().str.strip()
print(df[utm_cols].isna().sum())

print(df[utm_cols].head())
# Out:
# utm_source      0
# utm_medium      0
# utm_campaign    0
# dtype: int64
#   utm_source utm_medium utm_campaign
# 0    unknown    unknown      unknown
# 1    unknown    unknown      unknown
# 2    unknown    unknown      unknown
# 3    unknown    unknown      unknown
# 4    unknown    unknown      unknown

# %% [markdown]
# UTM-метки были нормализованы для корректной агрегации
# и устранения дубликатов.

# %%
df["is_success"] = df["Lead stage"].str.contains("получил материалы", case=False)

conversion = (
    df
    .groupby("utm_source")["is_success"]
    .mean()
    .sort_values(ascending=False)
    * 100
)
conversion
# Out:
# utm_source
# unknown    15.789474
# Name: is_success, dtype: float64

# %%
conversion.plot(
    kind="bar",
    title="Конверсия по источникам (%)"
)

plt.ylabel("Конверсия, %")
plt.show()

# %% [markdown]
# В качестве целевого действия был выбран статус
# «Получил материалы», который интерпретируется
# как успешный лид.

# %%
campaign_analysis = (
    df
    .groupby("utm_campaign")
    .agg(
        leads_count=("utm_campaign", "count"),
        conversion_rate=("is_success", "mean")
    )
    .reset_index()
)

campaign_analysis["conversion_rate"] *= 100

campaign_analysis
# Out:
#   utm_campaign  leads_count  conversion_rate
# 0      unknown           19        15.789474

# %%
campaign_analysis = campaign_analysis[
    campaign_analysis["leads_count"] >= 3
]

campaign_analysis
# Out:
#   utm_campaign  leads_count  conversion_rate
# 0      unknown           19        15.789474

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    campaign_analysis["leads_count"],
    campaign_analysis["conversion_rate"]
)

for _, row in campaign_analysis.iterrows():
    plt.text(
        row["leads_count"] + 0.1,
        row["conversion_rate"] + 0.1,
        row["utm_campaign"],
        fontsize=8
    )

plt.title("Эффективность рекламных кампаний")
plt.xlabel("Количество лидов")
plt.ylabel("Конверсия (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# рез-ты кампании: пик активности без идентифицированных источников.

# %% [markdown]
# Итоговый вывод по анализу лидов
#
# 1. Активность лидов сосредоточена в один день
#
# Все 19 лидов были созданы 25 сентября, что указывает на:
#
# - запуск рекламной кампании,
# - рассылку,
# - или единоразовый всплеск трафика.
#
# Это не «естественный поток», а разовый пик.
#
# 2. Большинство лидов не дошли до целевого действия
#
# Статусы показывают, что:
#
# - много лидов в категориях «Закрыто и не реализовано»,
# - часть — «ЯЩ (еще горячий, но уже остыл)»,
# - только небольшая доля дошла до статуса «Получил материалы».
#
#
# Это говорит о низкой конверсии в целевое действие.
#
#
# 3. Курсы распределены равномерно
